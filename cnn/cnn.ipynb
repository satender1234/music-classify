# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # MFCC extraction

# %%
import json
import os
import math
import librosa

DATASET_PATH = "/content/drive/MyDrive/genres/"
JSON_PATH = "data.json"
SAMPLE_RATE = 22050
TRACK_DURATION = 30 # measured in seconds
SAMPLES_PER_TRACK = SAMPLE_RATE * TRACK_DURATION


def extract_mfcc(dataset_path, json_path, num_mfcc=13, n_fft=2048, hop_length=512, num_segments=5):
    """Extracts MFCCs from music dataset and saves them into a json file along witgh genre labels.

    Params
    ------
        dataset_path (str): Path to dataset
        json_path (str): Path to json file used to save MFCCs
        num_mfcc (int): Number of coefficients to extract
        n_fft (int): Interval we consider to apply FFT. Measured in # of samples
        hop_length (int): Sliding window for FFT. Measured in # of samples
        num_segments (int): Number of segments we want to divide sample tracks into
    """

    # dictionary to store mapping, labels, and MFCCs
    data = {
        "mapping": [],
        "labels": [],
        "mfcc": []
    }

    samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
    num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / hop_length)

    # loop through all genres
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):
        if dirpath is not dataset_path:

            # save genre label (e.g: pop, blues,..) in the mapping
            semantic_label = dirpath.split("/")[-1]
            data["mapping"].append(semantic_label)
            print("\nProcessing: {}".format(semantic_label))

            # process all audio files in genre sub-dir
            for f in filenames:

		            # load audio file
                file_path = os.path.join(dirpath, f)
                signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)

                # process all segments of audio file
                for d in range(num_segments):

                    # calculate start and finish sample for current segment
                    start = samples_per_segment * d
                    finish = start + samples_per_segment

                    # extract mfcc
                    mfcc = librosa.feature.mfcc(signal[start:finish], sample_rate, n_mfcc=num_mfcc, n_fft=n_fft, hop_length=hop_length)
                    mfcc = mfcc.T

                    # store only mfcc feature with expected number of vectors
                    if len(mfcc) == num_mfcc_vectors_per_segment:
                        data["mfcc"].append(mfcc.tolist())
                        data["labels"].append(i-1)

    # save MFCCs to json file
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)
        
if __name__ == "__main__":  
    extract_mfcc(DATASET_PATH, JSON_PATH, num_segments=10)
# Out:
# Processing: country
#
# Processing: hiphop
#
# Processing: metal
#
# Processing: rock
#
# Processing: jazz
#
# Processing: blues
#
# Processing: pop
#
# Processing: disco
#
# Processing: reggae
#
# Processing: classical

# %% [markdown]
# # Create CNN model and train the data

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

import os
import pickle

import random

DATA_PATH = "data.json"


def load_data(data_path):
    """Loads training dataset from json file.
    Parameters
    ----------
    data_path (str): Path to json file containing data
    
    Returns
    -------
    X (ndarray): Inputs
    y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    return X, y

def prepare_datasets(test_size, validate_size):
    """Loads data and splits it into train, validate and test sets.

    Parameters
    ----------
    test_size (float): Value in [0, 1] indicating percentage of data set to allocate to test split
    validate_size (float): Value in [0, 1] indicating percentage of train set to allocate to validate split
    
    Returns
    -------
    X_train (ndarray): Input training set
    X_validate (ndarray): Input validate set
    X_test (ndarray): Input test set
    y_train (ndarray): Target training set
    y_validate (ndarray): Target validate set
    y_test (ndarray): Target test set
    """

    # load the data set
    X, y = load_data(DATA_PATH)

    # split the data set
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validate, y_train, y_validate = train_test_split(X_train, y_train, test_size=validate_size)

    # add an axis to input sets
    X_train = X_train[..., np.newaxis]
    X_validate = X_validate[..., np.newaxis]
    X_test = X_test[..., np.newaxis]

    return X_train, X_validate, X_test, y_train, y_validate, y_test


def build_model(ishape):
    """Generates CNN model

    Parameters
    ----------
    ishape (tuple): Shape of input set
    
    Returns
    -------
    model: CNN model
    """

    # build network topology
    model = keras.Sequential()

    # 1st convolutional layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=ishape))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 2nd convolutional layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu'))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 3rd convolutional layer
    model.add(keras.layers.Conv2D(32, (2, 2), activation='relu'))
    model.add(keras.layers.MaxPooling2D((2, 2), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # flatten output and feed it into dense layer
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dropout(0.3)) # avoid overfitting

    # output layer
    model.add(keras.layers.Dense(10, activation='softmax'))

    return model


if __name__ == "__main__":

    # splits the dataset into: train, test and validate sets
    # after the split, the train set is 60%, the test set is 25% and the validate set is 15% of the data set
    X_train, X_validate, X_test, y_train, y_validate, y_test = prepare_datasets(0.25, 0.2)

    # create CNN
    input_shape = (X_train.shape[1], X_train.shape[2], 1)
    model = build_model(input_shape)

    # compile model
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.0001),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_validate, y_validate), batch_size=32, epochs=80) 

    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)
    print('\nTest loss:', test_loss)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 128, 11, 32)       320
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 64, 6, 32)         0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 64, 6, 32)         128
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 62, 4, 32)         9248
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 31, 2, 32)         0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 31, 2, 32)         128
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 30, 1, 32)         4128
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 15, 1, 32)         0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 15, 1, 32)         128
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 480)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                30784
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                650
# =================================================================
# Total params: 45,514
# Trainable params: 45,322
# Non-trainable params: 192
# _________________________________________________________________
# Epoch 1/80
# 188/188 [==============================] - 12s 60ms/step - loss: 2.4721 - accuracy: 0.2269 - val_loss: 1.9047 - val_accuracy: 0.3353
# Epoch 2/80
# 188/188 [==============================] - 11s 59ms/step - loss: 1.9115 - accuracy: 0.3457 - val_loss: 1.6646 - val_accuracy: 0.3993
# Epoch 3/80
# 188/188 [==============================] - 11s 59ms/step - loss: 1.6864 - accuracy: 0.4177 - val_loss: 1.5238 - val_accuracy: 0.4527
# Epoch 4/80
# 188/188 [==============================] - 11s 59ms/step - loss: 1.5404 - accuracy: 0.4619 - val_loss: 1.4066 - val_accuracy: 0.4967
# Epoch 5/80
# 188/188 [==============================] - 11s 59ms/step - loss: 1.4497 - accuracy: 0.4822 - val_loss: 1.3445 - val_accuracy: 0.5253
# Epoch 6/80
# 188/188 [==============================] - 11s 59ms/step - loss: 1.3500 - accuracy: 0.5218 - val_loss: 1.2940 - val_accuracy: 0.5473
# Epoch 7/80
# 188/188 [==============================] - 11s 59ms/step - loss: 1.3172 - accuracy: 0.5288 - val_loss: 1.2499 - val_accuracy: 0.5573
# Epoch 8/80
# 188/188 [==============================] - 11s 60ms/step - loss: 1.2369 - accuracy: 0.5621 - val_loss: 1.2241 - val_accuracy: 0.5527
# Epoch 9/80
# 188/188 [==============================] - 11s 59ms/step - loss: 1.1982 - accuracy: 0.5721 - val_loss: 1.1749 - val_accuracy: 0.5867
# Epoch 10/80
# 188/188 [==============================] - 11s 59ms/step - loss: 1.1607 - accuracy: 0.5843 - val_loss: 1.1537 - val_accuracy: 0.5893
# Epoch 11/80
# 188/188 [==============================] - 11s 59ms/step - loss: 1.1075 - accuracy: 0.6125 - val_loss: 1.1286 - val_accuracy: 0.6113
# Epoch 12/80
# 188/188 [==============================] - 11s 59ms/step - loss: 1.0797 - accuracy: 0.6138 - val_loss: 1.0953 - val_accuracy: 0.6147
# Epoch 13/80
# 188/188 [==============================] - 11s 60ms/step - loss: 1.0544 - accuracy: 0.6268 - val_loss: 1.0761 - val_accuracy: 0.6207
# Epoch 14/80
# 188/188 [==============================] - 11s 59ms/step - loss: 1.0255 - accuracy: 0.6330 - val_loss: 1.0581 - val_accuracy: 0.6360
# Epoch 15/80
# 188/188 [==============================] - 11s 60ms/step - loss: 1.0107 - accuracy: 0.6512 - val_loss: 1.0546 - val_accuracy: 0.6307
# Epoch 16/80
# 188/188 [==============================] - 11s 59ms/step - loss: 0.9552 - accuracy: 0.6662 - val_loss: 1.0255 - val_accuracy: 0.6447
# Epoch 17/80
# 188/188 [==============================] - 11s 59ms/step - loss: 0.9252 - accuracy: 0.6722 - val_loss: 1.0157 - val_accuracy: 0.6453
# Epoch 18/80
# 188/188 [==============================] - 11s 59ms/step - loss: 0.9217 - accuracy: 0.6735 - val_loss: 1.0038 - val_accuracy: 0.6533
# Epoch 19/80
# 188/188 [==============================] - 11s 59ms/step - loss: 0.8922 - accuracy: 0.6875 - val_loss: 1.0023 - val_accuracy: 0.6500
# Epoch 20/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.8559 - accuracy: 0.6998 - val_loss: 0.9743 - val_accuracy: 0.6727
# Epoch 21/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.8586 - accuracy: 0.6982 - val_loss: 0.9567 - val_accuracy: 0.6687
# Epoch 22/80
# 188/188 [==============================] - 11s 59ms/step - loss: 0.8402 - accuracy: 0.7114 - val_loss: 0.9789 - val_accuracy: 0.6647
# Epoch 23/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.8212 - accuracy: 0.7122 - val_loss: 0.9499 - val_accuracy: 0.6740
# Epoch 24/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.7858 - accuracy: 0.7222 - val_loss: 0.9750 - val_accuracy: 0.6520
# Epoch 25/80
# 188/188 [==============================] - 11s 59ms/step - loss: 0.7794 - accuracy: 0.7255 - val_loss: 0.9234 - val_accuracy: 0.6880
# Epoch 26/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.7686 - accuracy: 0.7337 - val_loss: 0.9405 - val_accuracy: 0.6760
# Epoch 27/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.7487 - accuracy: 0.7322 - val_loss: 0.9273 - val_accuracy: 0.6773
# Epoch 28/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.7412 - accuracy: 0.7399 - val_loss: 0.9087 - val_accuracy: 0.6807
# Epoch 29/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.7285 - accuracy: 0.7462 - val_loss: 0.9032 - val_accuracy: 0.6887
# Epoch 30/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.6945 - accuracy: 0.7565 - val_loss: 0.9340 - val_accuracy: 0.6793
# Epoch 31/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.6724 - accuracy: 0.7602 - val_loss: 0.9201 - val_accuracy: 0.6940
# Epoch 32/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.6674 - accuracy: 0.7764 - val_loss: 0.9283 - val_accuracy: 0.6827
# Epoch 33/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.6605 - accuracy: 0.7707 - val_loss: 0.9147 - val_accuracy: 0.6720
# Epoch 34/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.6508 - accuracy: 0.7721 - val_loss: 0.8963 - val_accuracy: 0.7000
# Epoch 35/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.6197 - accuracy: 0.7847 - val_loss: 0.8969 - val_accuracy: 0.6960
# Epoch 36/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.6153 - accuracy: 0.7881 - val_loss: 0.8960 - val_accuracy: 0.6967
# Epoch 37/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.6215 - accuracy: 0.7826 - val_loss: 0.8973 - val_accuracy: 0.6900
# Epoch 38/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.5842 - accuracy: 0.7987 - val_loss: 0.9065 - val_accuracy: 0.6807
# Epoch 39/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.5864 - accuracy: 0.7969 - val_loss: 0.8800 - val_accuracy: 0.7067
# Epoch 40/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.5761 - accuracy: 0.7969 - val_loss: 0.8740 - val_accuracy: 0.6980
# Epoch 41/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.5593 - accuracy: 0.8106 - val_loss: 0.8768 - val_accuracy: 0.7067
# Epoch 42/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.5630 - accuracy: 0.8081 - val_loss: 0.8803 - val_accuracy: 0.7147
# Epoch 43/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.5456 - accuracy: 0.8082 - val_loss: 0.8674 - val_accuracy: 0.7027
# Epoch 44/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.5201 - accuracy: 0.8172 - val_loss: 0.8692 - val_accuracy: 0.7093
# Epoch 45/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.5293 - accuracy: 0.8176 - val_loss: 0.8591 - val_accuracy: 0.7120
# Epoch 46/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.5217 - accuracy: 0.8184 - val_loss: 0.9028 - val_accuracy: 0.7013
# Epoch 47/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.4945 - accuracy: 0.8327 - val_loss: 0.8782 - val_accuracy: 0.7067
# Epoch 48/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.5054 - accuracy: 0.8247 - val_loss: 0.8873 - val_accuracy: 0.7053
# Epoch 49/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.4869 - accuracy: 0.8329 - val_loss: 0.8729 - val_accuracy: 0.7067
# Epoch 50/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.4809 - accuracy: 0.8351 - val_loss: 0.8739 - val_accuracy: 0.7100
# Epoch 51/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.4594 - accuracy: 0.8396 - val_loss: 0.8701 - val_accuracy: 0.7213
# Epoch 52/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.4534 - accuracy: 0.8446 - val_loss: 0.8685 - val_accuracy: 0.7060
# Epoch 53/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.4433 - accuracy: 0.8474 - val_loss: 0.8877 - val_accuracy: 0.7113
# Epoch 54/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.4499 - accuracy: 0.8458 - val_loss: 0.8977 - val_accuracy: 0.7127
# Epoch 55/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.4281 - accuracy: 0.8568 - val_loss: 0.8937 - val_accuracy: 0.7160
# Epoch 56/80
# 188/188 [==============================] - 11s 61ms/step - loss: 0.4311 - accuracy: 0.8524 - val_loss: 0.8719 - val_accuracy: 0.7120
# Epoch 57/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.4322 - accuracy: 0.8518 - val_loss: 0.9095 - val_accuracy: 0.7033
# Epoch 58/80
# 188/188 [==============================] - 11s 61ms/step - loss: 0.4295 - accuracy: 0.8526 - val_loss: 0.9324 - val_accuracy: 0.7053
# Epoch 59/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.4067 - accuracy: 0.8616 - val_loss: 0.8854 - val_accuracy: 0.7140
# Epoch 60/80
# 188/188 [==============================] - 11s 61ms/step - loss: 0.3975 - accuracy: 0.8674 - val_loss: 0.9374 - val_accuracy: 0.7067
# Epoch 61/80
# 188/188 [==============================] - 11s 61ms/step - loss: 0.3880 - accuracy: 0.8673 - val_loss: 0.9007 - val_accuracy: 0.7153
# Epoch 62/80
# 188/188 [==============================] - 11s 61ms/step - loss: 0.3838 - accuracy: 0.8694 - val_loss: 0.9133 - val_accuracy: 0.7073
# Epoch 63/80
# 188/188 [==============================] - 11s 61ms/step - loss: 0.3721 - accuracy: 0.8723 - val_loss: 0.9037 - val_accuracy: 0.7087
# Epoch 64/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.3792 - accuracy: 0.8691 - val_loss: 0.9592 - val_accuracy: 0.6893
# Epoch 65/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.3648 - accuracy: 0.8753 - val_loss: 0.8682 - val_accuracy: 0.7233
# Epoch 66/80
# 188/188 [==============================] - 11s 61ms/step - loss: 0.3564 - accuracy: 0.8803 - val_loss: 0.9215 - val_accuracy: 0.7047
# Epoch 67/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.3532 - accuracy: 0.8791 - val_loss: 0.9012 - val_accuracy: 0.7207
# Epoch 68/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.3498 - accuracy: 0.8794 - val_loss: 0.8881 - val_accuracy: 0.7160
# Epoch 69/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.3386 - accuracy: 0.8869 - val_loss: 0.9539 - val_accuracy: 0.7120
# Epoch 70/80
# 188/188 [==============================] - 11s 61ms/step - loss: 0.3344 - accuracy: 0.8881 - val_loss: 0.9426 - val_accuracy: 0.7113
# Epoch 71/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.3387 - accuracy: 0.8821 - val_loss: 0.9093 - val_accuracy: 0.7153
# Epoch 72/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.3214 - accuracy: 0.8899 - val_loss: 0.9005 - val_accuracy: 0.7287
# Epoch 73/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.3270 - accuracy: 0.8898 - val_loss: 0.9222 - val_accuracy: 0.7213
# Epoch 74/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.3187 - accuracy: 0.8903 - val_loss: 0.9072 - val_accuracy: 0.7233
# Epoch 75/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.3084 - accuracy: 0.8954 - val_loss: 0.9300 - val_accuracy: 0.7180
# Epoch 76/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.3111 - accuracy: 0.8941 - val_loss: 0.9416 - val_accuracy: 0.7093
# Epoch 77/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.2990 - accuracy: 0.8984 - val_loss: 0.9462 - val_accuracy: 0.7053
# Epoch 78/80
# 188/188 [==============================] - 11s 61ms/step - loss: 0.2967 - accuracy: 0.9025 - val_loss: 0.9077 - val_accuracy: 0.7260
# Epoch 79/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.2943 - accuracy: 0.9040 - val_loss: 0.9392 - val_accuracy: 0.7200
# Epoch 80/80
# 188/188 [==============================] - 11s 60ms/step - loss: 0.2903 - accuracy: 0.8998 - val_loss: 0.9243 - val_accuracy: 0.7100
# 79/79 - 1s - loss: 0.7977 - accuracy: 0.7499
#
# Test accuracy: 0.7498999834060669
#
# Test loss: 0.7977221608161926

# %% [markdown]
# # Predict using test set

# %%
def predict(model, X, y):
    """Predict a single sample using the trained model

    Parameters
    ----------

    model: Trained classifier
    X: Input data
    y (int): Target
    """

    # add a dimension to input data for sample - model.predict() expects a 4d array in this case
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)

    # perform prediction
    prediction = model.predict(X)

    # get index with max value
    predicted_index = np.argmax(prediction, axis=1)

    return y, predicted_index

def print_predict(number):
    """ Prints random predicts

    Parameters
    ----------
    number: number of samples
    """

    for i in range(10):
      rand = random.randint(0, len(X_test))
      y, predicted_index = predict(model, X_test[rand], y_test[rand])
      print("Target: {}".format(genres[y]))
      print("Predicted label: {}\n".format(genres[predicted_index[0]]))


if __name__ == "__main__":
    # get genre label
    with open(DATA_PATH, "r") as fp:
        data = json.load(fp)

    genres = np.array(data["mapping"])
    
    # print predict for 10 random selected sample
    print_predict(10)
# Out:
# Target: classical
# Predicted label: classical
#
# Target: hiphop
# Predicted label: hiphop
#
# Target: country
# Predicted label: jazz
#
# Target: metal
# Predicted label: metal
#
# Target: blues
# Predicted label: blues
#
# Target: country
# Predicted label: country
#
# Target: country
# Predicted label: rock
#
# Target: disco
# Predicted label: rock
#
# Target: blues
# Predicted label: blues
#
# Target: blues
# Predicted label: blues

# %% [markdown]
# # Plot accuracy and loss

# %%
def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs

    Parameters
    ----------
    history: Training history of model
    """

    fig, axs = plt.subplots(2, figsize=(15,15))

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy evaluation")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error evaluation")

    plt.show()


if __name__ == "__main__":
    plot_history(history)
